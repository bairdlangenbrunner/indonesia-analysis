# %%
import pandas
import numpy
import datetime

# %%
filename = '/Users/baird/Dropbox/_data_observations/ASIAFLUX/PSO/FxMt_PSO_2004_30m_04/FxMT_PSO_2004_30m_04.csv'

# %%
date_parse = lambda *columns: datetime.

# %%
pso_2004 = pandas.read_csv(filename, header=[0,1])

# %%
pso_2004.head()
# Out:
#                 Year                DOY               TIME              Fc  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1 micromol m-2 -1
# 0               2004                  1                 30        2.912090
# 1               2004                  1                100        9.297709
# 2               2004                  1                130        3.025224
# 3               2004                  1                200        1.458552
# 4               2004                  1                230       15.181820
#
#                Sc          H         LE             NEE       Ust   Rgs  \
#   micromol m-2 -1      W m-2      W m-2 micromol m-2 -1     m s-2 W m-2
# 0   -99999.000000 -46.633289  20.873039   -99999.000000  0.274470   0.0
# 1       -1.779076 -39.770439  23.724888        7.518634  0.303769   0.0
# 2       -1.467086 -46.029743   7.200397        1.558139  0.219004   0.0
# 3        2.263368 -35.505283   2.917072        3.721920  0.116208   0.0
# ...

# %%
a = pso_2004['Year'].values.flatten()

# %%
a
# Out:
# array([2004, 2004, 2004, ..., 2004, 2004, 2004])

# %%
datetime.datetime()

# %%
datetime.datetime([2015,2016],1,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-a2d5b0c5b0bb> in <module>()
# ----> 1 datetime.datetime([2015,2016],1,1)
#
# TypeError: an integer is required (got type list)

# %%
datetime_list = [datetime.datetime(int(pso_2004['Year'].values.flatten()[i]),1,1)\
                 +datetime.timedelta(int(pso_2004['DOY'].values.flatten()[i])-1) \
                 for i in range(pso_2004['Year'].values.flatten().size)]

# %%
datetime_list
# Out:
# [datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
#  datetime.datetime(2004, 1, 1, 0, 0),
# ...
